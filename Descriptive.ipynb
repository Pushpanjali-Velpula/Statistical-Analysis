# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushpanjali-Velpula/Statistical-Analysis/blob/main/Descriptive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics
member_names=["Aman","Riya","Karan","Sneha","Rahul"]
ages=[22,25,24,23,26]
workout_hours=[2,1.5,2.5,1,3]
calories_burned=[500,350,600,300,750]
print("--------Fitness Center Dataset--------")
for i in range(len(member_names)):
    print(member_names[i],
          ages[i],
          workout_hours[i],
          calories_burned[i])
print("\n")
average_workout=sum(workout_hours)/len(workout_hours)
print("Average workout hours=",average_workout)

highest_calories=max(calories_burned)
print("Maximum calories burned=",highest_calories)

lowest_calories=min(calories_burned)
print("Minimum calories burned=",lowest_calories)

median_calories=statistics.median(calories_burned)
print("Median calories burned=",median_calories)

std_dev=statistics.stdev(calories_burned)
print("Standard Deviation=",std_dev)

index=calories_burned.index(highest_calories)
print("Most Active Member=",member_names[index])
# Out:
# --------Fitness Center Dataset--------
# Aman 22 2 500
# Riya 25 1.5 350
# Karan 24 2.5 600
# Sneha 23 1 300
# Rahul 26 3 750
#
#
# Average workout hours= 2.0
# Maximum calories burned= 750
# Minimum calories burned= 300
# Median calories burned= 500
# Standard Deviation= 183.71173070873834
# Most Active Member= Rahul

# %%
import matplotlib.pyplot as plt
plt.bar(member_names,calories_burned)
plt.xlabel("Member Names")
plt.ylabel("Calories Burned")
plt.title("Fitness Analysis")
plt.show()

plt.scatter(member_names,calories_burned)
plt.xlabel("Member Names")
plt.ylabel("Calories Burned")
plt.title("Fitness Analysis")
plt.show()
