# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushpanjali-Velpula/Statistical-Analysis/blob/main/FitnessDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import median
import pandas as pd
import statistics
import matplotlib.pyplot as plt

data=pd.read_csv("/content/fitness dataset.csv")
data.drop_duplicates(inplace=True)
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)
print(data)
print("-------------------")
average_workout=sum(data['Session_duration'])/len(data['Session_duration'])
print("Average Session Duration =",average_workout)
average_calories=sum(data['Calories_Burned'])/len(data['Calories_Burned'])
print("Average Calories Burned =",average_calories)
highest_calories=max(data['Calories_Burned'])
print("Highest Calories Burned =",highest_calories)
lowest_calories=min(data['Calories_Burned'])
print("Lowest Calories Burned =",lowest_calories)
median_calories=median(data['Calories_Burned'])
print("Median Calories Burned =",median_calories)
stddev=statistics.stdev(data['Calories_Burned'])
print("Standard Deviation =",stddev)
index=data['Calories_Burned'].idxmax()
print("Most Active Member has burned",data['Calories_Burned'][index],"calories")


plt.hist(data['Calories_Burned'])
plt.xlabel("Workout(days)")
plt.ylabel("Frequency")
plt.title("Calories_Burned")
plt.show()

plt.scatter(data['Session_duration'],data['Calories_Burned'])
plt.xlabel("Session_duration")
plt.ylabel("Calories_Burned")
plt.title("Fitness Analysis")
plt.show()

gender_counts = data['Gender'].value_counts()
plt.title("Gender Distribution")
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.show()
# Out:
#     Age  Gender  Session_duration  Calories_Burned  Workout(days)
# 0    34  Female              1.12              712              5
# 1    26  Female              1.00              833              5
# 2    22    Male              1.24             1678              3
# 3    54  Female              1.45              628              4
# 4    38  Female              1.62              953              2
# ..  ...     ...               ...              ...            ...
# 79   52    Male              1.95             1205              5
# 80   36    Male              1.46             1108              3
# 81   58    Male              1.45             1019              2
# 82   55    Male              1.18              335              2
# 83   57    Male              1.30              983              3
#
# [84 rows x 5 columns]
# -------------------
# Average Session Duration = 1.3858333333333333
# Average Calories Burned = 1023.4880952380952
# Highest Calories Burned = 1783
# ...
